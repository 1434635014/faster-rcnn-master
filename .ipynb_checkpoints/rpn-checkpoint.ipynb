# %%
import keras.layers as KL
from keras.models import Model
import keras.backend as K
import tensorflow as tf
import numpy as np
import keras
import voc_data
import importlib
import config
import math
from keras.callbacks import LearningRateScheduler
from keras.utils.vis_utils import plot_model

importlib.reload(voc_data)
importlib.reload(config)

config = config.Config()
image_size = config.image_size[0]
anchor_num = len(config.scales) * len(config.ratios) # 一个锚点对应的anchor数量
anchors = voc_data._anchors
# Out:
# Using TensorFlow backend.
# 56
# 21
# 56
# 21

# %%
imgList, bboxList, class_idList, rpn_matchList, rpn_bboxesList, maxTwoNum, anchorsList = voc_data.getAllImage()
print(len(imgList))
print(maxTwoNum)
print(maxTwoNum / (1))

# %%
class BatchNorm(KL.BatchNormalization):
    def call(self, inputs, training=None):
        return super(self.__class__, self).call(inputs, training=False)

# ResNet网络 的building_block
# filter：卷积核的通道数
# block：block的标识
def building_block(filters, block):
    if block != 0:
        stride = 1
    else:
        stride = 2
    
    def f(x):
        y = KL.Conv2D(filters, (1,1), strides=stride)(x)
        y = BatchNorm(axis=3)(y)
        y = KL.Activation("relu")(y)
        
        y = KL.Conv2D(filters, (3,3), padding="same")(y)
        y = BatchNorm(axis=3)(y)
        y = KL.Activation("relu")(y)
        
        y = KL.Conv2D(4 * filters, (1,1))(y)
        y = BatchNorm(axis=3)(y)
        
        if block == 0:
            # 保证shorcut的filters和上面y的filters个数一致
            shorcut = KL.Conv2D(4 * filters, (1,1), strides=stride)(x)
            shorcut = BatchNorm(axis=3)(shorcut)
        else:
            shorcut = x

        # 结合两个支路的输出
        y = KL.Add()([y, shorcut])
        y = KL.Activation("relu")(y)
        return y
    return f

# ResNet网络
def resNet_featureExtractor(inputs):
    filters = 64   # 第一个卷积核的通道数
    x = KL.Conv2D(filters, (2,2), strides=2)(inputs)
    x = BatchNorm(axis=3)(x)
    x = KL.Activation("relu")(x)

    # resnet50
    blocks = [8, 8, 8]    # buildblock的数量  change
    
    for i, block_num in enumerate(blocks):
        for block_id in range(block_num):
            x = building_block(filters, block_id)(x)
        filters = filters * 2
    return x

def rpn_net(inputs, k):
    shared_map = KL.Conv2D(256, (3,3), padding="same")(inputs)
    shared_map = KL.Activation("linear")(shared_map)
    rpn_class = KL.Conv2D(2 * k, (1,1))(shared_map)
    rpn_class = KL.Lambda(lambda x: tf.reshape(x, [tf.shape(x)[0], -1, 2]))(rpn_class)
    rpn_class = KL.Activation("linear")(rpn_class)
    # 分类的得分
    rpn_prob = KL.Activation("softmax")(rpn_class)
    
    y = KL.Conv2D(4*k, (1,1))(shared_map)
    y = KL.Activation("linear")(y)
    # 边框的得分
    rpn_bbox = KL.Lambda(lambda x: tf.reshape(x, [tf.shape(x)[0], -1, 4]))(y)
    
    return rpn_class, rpn_prob, rpn_bbox

# %%
x = KL.Input((config.image_size[0], config.image_size[0], 3))  # change
fp = resNet_featureExtractor(x)
rpn_class, rpn_prob, rpn_bbox = rpn_net(fp, anchor_num)
model = Model([x], [rpn_class, rpn_prob, rpn_bbox])
model.summary()
# plot_model(model, to_file="model/model.png", show_shapes=True)
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:68: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:508: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3837: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 320, 320, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 64) 832         input_1[0][0]
# __________________________________________________________________________________________________
# batch_norm_1 (BatchNorm)        (None, 160, 160, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 160, 160, 64) 0           batch_norm_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 80, 80, 64)   4160        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_norm_2 (BatchNorm)        (None, 80, 80, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 80, 80, 64)   0           batch_norm_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 80, 80, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_norm_3 (BatchNorm)        (None, 80, 80, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 80, 80, 64)   0           batch_norm_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 80, 80, 256)  16640       activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 80, 256)  16640       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_norm_4 (BatchNorm)        (None, 80, 80, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_norm_5 (BatchNorm)        (None, 80, 80, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 80, 80, 256)  0           batch_norm_4[0][0]
#                                                                  batch_norm_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 80, 80, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 80, 80, 64)   16448       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_norm_6 (BatchNorm)        (None, 80, 80, 64)   256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 80, 80, 64)   0           batch_norm_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 80, 80, 64)   36928       activation_5[0][0]
# __________________________________________________________________________________________________
# batch_norm_7 (BatchNorm)        (None, 80, 80, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 80, 80, 64)   0           batch_norm_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 80, 80, 256)  16640       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_norm_8 (BatchNorm)        (None, 80, 80, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 80, 80, 256)  0           batch_norm_8[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 80, 80, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 80, 80, 64)   16448       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_norm_9 (BatchNorm)        (None, 80, 80, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 80, 80, 64)   0           batch_norm_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 80, 80, 64)   36928       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_norm_10 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 80, 80, 64)   0           batch_norm_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 80, 80, 256)  16640       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_norm_11 (BatchNorm)       (None, 80, 80, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 80, 80, 256)  0           batch_norm_11[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 80, 80, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 80, 80, 64)   16448       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_norm_12 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 80, 80, 64)   0           batch_norm_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 80, 80, 64)   36928       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_norm_13 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 80, 80, 64)   0           batch_norm_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 80, 80, 256)  16640       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_norm_14 (BatchNorm)       (None, 80, 80, 256)  1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 80, 80, 256)  0           batch_norm_14[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 80, 80, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 80, 80, 64)   16448       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_norm_15 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 80, 80, 64)   0           batch_norm_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 80, 80, 64)   36928       activation_14[0][0]
# __________________________________________________________________________________________________
# batch_norm_16 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 80, 80, 64)   0           batch_norm_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 80, 80, 256)  16640       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_norm_17 (BatchNorm)       (None, 80, 80, 256)  1024        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 80, 80, 256)  0           batch_norm_17[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 80, 80, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 80, 80, 64)   16448       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_norm_18 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 80, 80, 64)   0           batch_norm_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 80, 80, 64)   36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_norm_19 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 80, 80, 64)   0           batch_norm_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 80, 80, 256)  16640       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_norm_20 (BatchNorm)       (None, 80, 80, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 80, 80, 256)  0           batch_norm_20[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 80, 80, 256)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 80, 80, 64)   16448       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_norm_21 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 80, 80, 64)   0           batch_norm_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 80, 80, 64)   36928       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_norm_22 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 80, 80, 64)   0           batch_norm_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 80, 80, 256)  16640       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_norm_23 (BatchNorm)       (None, 80, 80, 256)  1024        conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 80, 80, 256)  0           batch_norm_23[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 80, 80, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 80, 80, 64)   16448       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_norm_24 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 80, 80, 64)   0           batch_norm_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 80, 80, 64)   36928       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_norm_25 (BatchNorm)       (None, 80, 80, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 80, 80, 64)   0           batch_norm_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 80, 80, 256)  16640       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_norm_26 (BatchNorm)       (None, 80, 80, 256)  1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 80, 80, 256)  0           batch_norm_26[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 80, 80, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 40, 40, 128)  32896       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_norm_27 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 40, 40, 128)  0           batch_norm_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 40, 40, 128)  147584      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_norm_28 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 40, 40, 128)  0           batch_norm_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 40, 40, 512)  66048       activation_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 40, 40, 512)  131584      activation_25[0][0]
# __________________________________________________________________________________________________
# batch_norm_29 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_norm_30 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 40, 40, 512)  0           batch_norm_29[0][0]
#                                                                  batch_norm_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 40, 40, 512)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 40, 40, 128)  65664       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_norm_31 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 40, 40, 128)  0           batch_norm_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 40, 40, 128)  147584      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_norm_32 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 40, 40, 128)  0           batch_norm_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 40, 40, 512)  66048       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_norm_33 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 40, 40, 512)  0           batch_norm_33[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 40, 40, 512)  0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 40, 40, 128)  65664       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_norm_34 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 40, 40, 128)  0           batch_norm_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 40, 40, 128)  147584      activation_32[0][0]
# __________________________________________________________________________________________________
# batch_norm_35 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 40, 40, 128)  0           batch_norm_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 40, 40, 512)  66048       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_norm_36 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 40, 40, 512)  0           batch_norm_36[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 40, 40, 512)  0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 40, 40, 128)  65664       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_norm_37 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 40, 40, 128)  0           batch_norm_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 40, 40, 128)  147584      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_norm_38 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 40, 40, 128)  0           batch_norm_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 40, 40, 512)  66048       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_norm_39 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 40, 40, 512)  0           batch_norm_39[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 40, 40, 512)  0           add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 40, 40, 128)  65664       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_norm_40 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 40, 40, 128)  0           batch_norm_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 40, 40, 128)  147584      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_norm_41 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 40, 40, 128)  0           batch_norm_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 40, 40, 512)  66048       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_norm_42 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 40, 40, 512)  0           batch_norm_42[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 40, 40, 512)  0           add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 40, 40, 128)  65664       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_norm_43 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 40, 40, 128)  0           batch_norm_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 40, 40, 128)  147584      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_norm_44 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 40, 40, 128)  0           batch_norm_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 40, 40, 512)  66048       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_norm_45 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 40, 40, 512)  0           batch_norm_45[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 40, 40, 512)  0           add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 40, 40, 128)  65664       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_norm_46 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 40, 40, 128)  0           batch_norm_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 40, 40, 128)  147584      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_norm_47 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 40, 40, 128)  0           batch_norm_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 40, 40, 512)  66048       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_norm_48 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_48[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 40, 40, 512)  0           batch_norm_48[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 40, 40, 512)  0           add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 40, 40, 128)  65664       activation_46[0][0]
# __________________________________________________________________________________________________
# batch_norm_49 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 40, 40, 128)  0           batch_norm_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 40, 40, 128)  147584      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_norm_50 (BatchNorm)       (None, 40, 40, 128)  512         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 40, 40, 128)  0           batch_norm_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 40, 40, 512)  66048       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_norm_51 (BatchNorm)       (None, 40, 40, 512)  2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 40, 40, 512)  0           batch_norm_51[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 40, 40, 512)  0           add_16[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 20, 20, 256)  131328      activation_49[0][0]
# __________________________________________________________________________________________________
# batch_norm_52 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 20, 20, 256)  0           batch_norm_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 20, 20, 256)  590080      activation_50[0][0]
# __________________________________________________________________________________________________
# batch_norm_53 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 20, 20, 256)  0           batch_norm_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 20, 20, 1024) 263168      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 20, 20, 1024) 525312      activation_49[0][0]
# __________________________________________________________________________________________________
# batch_norm_54 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_norm_55 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_55[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 20, 20, 1024) 0           batch_norm_54[0][0]
#                                                                  batch_norm_55[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 20, 20, 1024) 0           add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 20, 20, 256)  262400      activation_52[0][0]
# __________________________________________________________________________________________________
# batch_norm_56 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 20, 20, 256)  0           batch_norm_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 20, 20, 256)  590080      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_norm_57 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 20, 20, 256)  0           batch_norm_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 20, 20, 1024) 263168      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_norm_58 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 20, 20, 1024) 0           batch_norm_58[0][0]
#                                                                  activation_52[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 20, 20, 1024) 0           add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 20, 20, 256)  262400      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_norm_59 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 20, 20, 256)  0           batch_norm_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 20, 20, 256)  590080      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_norm_60 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 20, 20, 256)  0           batch_norm_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 20, 20, 1024) 263168      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_norm_61 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_61[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 20, 20, 1024) 0           batch_norm_61[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 20, 20, 1024) 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 20, 20, 256)  262400      activation_58[0][0]
# __________________________________________________________________________________________________
# batch_norm_62 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 20, 20, 256)  0           batch_norm_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 20, 20, 256)  590080      activation_59[0][0]
# __________________________________________________________________________________________________
# batch_norm_63 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 20, 20, 256)  0           batch_norm_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 20, 20, 1024) 263168      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_norm_64 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_64[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 20, 20, 1024) 0           batch_norm_64[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 20, 20, 1024) 0           add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 20, 20, 256)  262400      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_norm_65 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 20, 20, 256)  0           batch_norm_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 20, 20, 256)  590080      activation_62[0][0]
# __________________________________________________________________________________________________
# batch_norm_66 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 20, 20, 256)  0           batch_norm_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 20, 20, 1024) 263168      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_norm_67 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_67[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 20, 20, 1024) 0           batch_norm_67[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 20, 20, 1024) 0           add_21[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 20, 20, 256)  262400      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_norm_68 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 20, 20, 256)  0           batch_norm_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 20, 20, 256)  590080      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_norm_69 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 20, 20, 256)  0           batch_norm_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 20, 20, 1024) 263168      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_norm_70 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_70[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 20, 20, 1024) 0           batch_norm_70[0][0]
#                                                                  activation_64[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 20, 20, 1024) 0           add_22[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 20, 20, 256)  262400      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_norm_71 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 20, 20, 256)  0           batch_norm_71[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 20, 20, 256)  590080      activation_68[0][0]
# __________________________________________________________________________________________________
# batch_norm_72 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 20, 20, 256)  0           batch_norm_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 20, 20, 1024) 263168      activation_69[0][0]
# __________________________________________________________________________________________________
# batch_norm_73 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_73[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 20, 20, 1024) 0           batch_norm_73[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 20, 20, 1024) 0           add_23[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 20, 20, 256)  262400      activation_70[0][0]
# __________________________________________________________________________________________________
# batch_norm_74 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 20, 20, 256)  0           batch_norm_74[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 20, 20, 256)  590080      activation_71[0][0]
# __________________________________________________________________________________________________
# batch_norm_75 (BatchNorm)       (None, 20, 20, 256)  1024        conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 20, 20, 256)  0           batch_norm_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 20, 20, 1024) 263168      activation_72[0][0]
# __________________________________________________________________________________________________
# batch_norm_76 (BatchNorm)       (None, 20, 20, 1024) 4096        conv2d_76[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 20, 20, 1024) 0           batch_norm_76[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 20, 20, 1024) 0           add_24[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 20, 20, 256)  2359552     activation_73[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 20, 20, 256)  0           conv2d_77[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 20, 20, 18)   4626        activation_74[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, 2)      0           conv2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 20, 20, 36)   9252        activation_74[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, 2)      0           lambda_1[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 20, 20, 36)   0           conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, 2)      0           activation_75[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, 4)      0           activation_77[0][0]
# ==================================================================================================
# Total params: 14,684,790
# Trainable params: 14,638,070
# Non-trainable params: 46,720
# __________________________________________________________________________________________________

# %%
# x：rpn_box，counts：anchor为1的个数，num_rows = len(counts)：总共多少个
# 小函数，取出rpn_box前面有值的“偏移量”
def batch_back(x, counts, num_rows):
    outputs = []
    for i in range(num_rows):
        outputs.append(x[i, :counts[i]])
    return tf.concat(outputs, axis=0)

# 分类loss
# rpn_match：真实下标  rpn_class_logits：实际计算出的结果
def rpn_class_loss(rpn_match, rpn_class_logits):
    # 压缩最后一维，变成一维的坐标，rpn_match (None, 576, 1) => (None, 576) 
    rpn_match = tf.squeeze(rpn_match, -1)
    # 取出 -1 和 1 的坐标
    indices = tf.where(K.not_equal(rpn_match, 0))
    # 把 -1 和 0 变成 0， 1 还是 1
    anchor_class = K.cast(K.equal(rpn_match, 1), tf.int32)
    # 取出实际计算出的所有-1 和 1坐标的anchor
    rpn_class_logits = tf.gather_nd(rpn_class_logits, indices)     ### prediction
    # 取出真实下标的所有-1 和 1坐标的anchor => 现在是（0, 1）0：表示背景 1：表示前景
    anchor_class = tf.gather_nd(anchor_class, indices)   ### target
    # 计算loss
    loss = K.sparse_categorical_crossentropy(target=anchor_class, output=rpn_class_logits, from_logits=True)
    # 计算平均，如果loss算出东西了，就取平均，如果没算出东西，就取0
    loss = K.switch(tf.size(loss) > 0 , K.mean(loss), tf.constant(0.0))
    return loss

# 回归loss
# target_bbox：真实的边框, rpn_match：真实的anchor下标, rpn_bbox：实际计算出来的结果边框
def rpn_bbox_loss(target_bbox, rpn_match, rpn_bbox):
    # 压缩最后一维，变成一维的坐标，rpn_match (None, 576, 1) => (None, 576) 
    rpn_match = tf.squeeze(rpn_match, -1)
    # 取出 1 的坐标
    indices = tf.where(K.equal(rpn_match, 1))
    # 取出所有 1 的“偏移量”
    rpn_bbox = tf.gather_nd(rpn_bbox, indices)
    # 得出为 1 的“偏移量”的个数
    batch_counts = K.sum(K.cast(K.equal(rpn_match, 1), tf.int32), axis=1)
    # 取出 target_bbox 中为1的“偏移量”
    target_bbox = batch_back(target_bbox, batch_counts, config.batch_size)
    # 求误差
    diff = K.abs(target_bbox - rpn_bbox)
    # 取出小于1的部分
    less_than_one = K.cast(K.less(diff, 1.0), "float32")
    # 小于1的部分给抛物线  diff**2
    # 大于1的部分给直线（不会对大的误差敏感） diff-0.5
    loss = (less_than_one * 0.5 * diff**2) + ((1 - less_than_one) * (diff - 0.5))
    # 计算平均，如果loss算出东西了，就取平均，如果没算出东西，就取0
    loss = K.switch(tf.size(loss) > 0 , K.mean(loss), tf.constant(0.0))
    return loss

# 图片的输入
input_image = KL.Input(shape=[config.image_size[0], config.image_size[0],3], dtype=tf.float32)  # change
# 真实的边框输入
input_bboxes = KL.Input(shape=[None, 4], dtype=tf.float32)
# 真实的分类输入
input_class_ids = KL.Input(shape=[None], dtype=tf.int32)
# 真实的anchor分类 -1,0,1输入
input_rpn_match = KL.Input(shape=[None, 1], dtype=tf.int32)
# 真实的anchor偏移量输入
input_rpn_bbox = KL.Input(shape=[None, 4], dtype=tf.float32)


# 创建模型
feature_map = resNet_featureExtractor(input_image)
# 模型计算出的结果 rpn_class，rpn_prob，rpn_bbox
rpn_class, rpn_prob, rpn_bbox = rpn_net(feature_map, anchor_num)
# 分类loss
loss_rpn_match = KL.Lambda(lambda x: rpn_class_loss(*x), name="loss_rpn_match")(
    [input_rpn_match, rpn_class]
)
loss_rpn_bbox = KL.Lambda(lambda x:rpn_bbox_loss(*x), name="loss_rpn_bbox")(
    [input_rpn_bbox, input_rpn_match, rpn_bbox]
)
model = Model(
    [input_image, input_bboxes, input_class_ids, input_rpn_match, input_rpn_bbox],
    [rpn_class, rpn_prob, rpn_bbox, loss_rpn_match, loss_rpn_bbox]
)
# 添加loss层
loss_lay1 = model.get_layer("loss_rpn_match").output
loss_lay2 = model.get_layer("loss_rpn_bbox").output
model.add_loss(tf.reduce_mean(loss_lay1))
model.add_loss(tf.reduce_mean(loss_lay2))
# 编译
model.compile(loss = [None] * len(model.output), optimizer=keras.optimizers.SGD(lr=0.0, momentum=0.9, decay=0.0, nesterov=False))
# 打印出两个loss的收敛情况
model.metrics_names.append("loss_rpn_match")
model.metrics_tensors.append(tf.reduce_mean(loss_lay1, keep_dims=True))
model.metrics_names.append("loss_rpn_bbox")
model.metrics_tensors.append(tf.reduce_mean(loss_lay2, keep_dims=True))
# Out:
# WARNING:tensorflow:From <ipython-input-4-ae7db8d23bf6>:15: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\optimizers.py:757: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# celeba
# def data_Gen(num_batch, batch_size, config):
#     print("----------------")
#     index = 0
#     for iii in range(num_batch):
#         images = []
#         bboxes = []
#         class_ids = []
#         rpn_matchs = []
#         rpn_bboxes = []
#         for i in range(batch_size):
#             image, bbox, class_id, rpn_match, rpn_bbox = imgList[index], bboxList[index], class_idList[index], rpn_matchList[index], rpn_bboxesList[index]
#             pad_num = config.max_gt_obj - bbox.shape[0]
#             pad_box = np.zeros((pad_num, 4))
#             pad_ids = np.zeros((pad_num, 1))
#             bbox = np.concatenate([bbox, pad_box], axis=0)
#             class_id = np.concatenate([class_id, pad_ids], axis=0)
        
#             images.append(image)
#             bboxes.append(bbox)
#             class_ids.append(class_id)
#             rpn_matchs.append(rpn_match)
#             rpn_bboxes.append(rpn_bbox)
#             index += 1
#             # 数据下标大于9996，重置为0
#             if index >= 16000:
#                 index = 0

# #         print("数据：" + str(index))
#         images = np.concatenate(images, 0).reshape(batch_size, config.image_size[0],config.image_size[1] , 3)
#         bboxes = np.concatenate(bboxes, 0).reshape(batch_size, -1 , 4)
#         class_ids = np.concatenate(class_ids, 0).reshape(batch_size, -1 )
#         rpn_matchs = np.concatenate(rpn_matchs, 0).reshape(batch_size, -1 , 1)
#         rpn_bboxes = np.concatenate(rpn_bboxes, 0).reshape(batch_size, -1 , 4)
#         yield [images, bboxes, class_ids, rpn_matchs, rpn_bboxes],[]
# total = 200000          # 总数据
# steps_per_epoch = 20   # 步长
# dataGen = data_Gen(int(total), config.batch_size, config) # 10000个数据，batch_size=10
# voc
def data_Gen(num_batch, batch_size, config, beginIndex):
    print("----------------")
    index = beginIndex
    for iii in range(num_batch):
        images = []
        bboxes = []
        class_ids = []
        rpn_matchs = []
        rpn_bboxes = []
        for i in range(batch_size):
            image, bbox, class_id, active_id, rpn_match, rpn_bbox, idxLen, anchors = voc_data.getAllImage(index)
            pad_num = config.max_gt_obj - bbox.shape[0]
            pad_box = np.zeros((pad_num, 4))
            pad_ids = np.zeros((pad_num, 1))
            bbox = np.concatenate([bbox, pad_box], axis=0)
            class_id = np.concatenate([class_id, pad_ids], axis=0)
        
            images.append(image)
            bboxes.append(bbox)
            class_ids.append(class_id)
            rpn_matchs.append(rpn_match)
            rpn_bboxes.append(rpn_bbox)
            index += 1
            # 数据下标大于16000，重置为0
            if index >= 16000:
                index = 0

        print("数据：" + str(index))
        images = np.concatenate(images, 0).reshape(batch_size, config.image_size[0],config.image_size[1] , 3)
        bboxes = np.concatenate(bboxes, 0).reshape(batch_size, -1 , 4)
        class_ids = np.concatenate(class_ids, 0).reshape(batch_size, -1 )
        rpn_matchs = np.concatenate(rpn_matchs, 0).reshape(batch_size, -1 , 1)
        rpn_bboxes = np.concatenate(rpn_bboxes, 0).reshape(batch_size, -1 , 4)
        yield [images, bboxes, class_ids, rpn_matchs, rpn_bboxes],[]

# 开始下标
beginIndex = 0
total = 200000          # 总数据
steps_per_epoch = 20   # 步长
dataGen = data_Gen(int(total), config.batch_size, config, beginIndex) # 10000个数据，batch_size=10

# %%
# face V2版本
# 参数1320万 320 × 320  batch_size：10 steps_per_epoch：20  rpn_stride：16  scales：[55, 60, 70, 85, 105, 140, 180, 230]  buildblock：[7,7,7]   文件名：model_224_16_[epochs数]_v2.h5
# 第一次20epochs lr=0.0001 batch_size：10  1w数据
# drop = 0.5 衰减率调小
# learning rate schedule
def step_decay(epoch):
    initial_lrate = 0.0001
    drop = 0.8
    epochs_drop = 5.0
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    print('学习率：' + str(lrate))
    return lrate
lrate = LearningRateScheduler(step_decay)
his = model.fit_generator(dataGen, steps_per_epoch=steps_per_epoch, epochs=20, callbacks=[lrate])
# Out:
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:977: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:964: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# ----------------Epoch 1/20
#
# 数据：10
# 数据：20
# 数据：30
# 数据：40
# 数据：50
# 数据：60
# 数据：70
# 数据：80
# 数据：90
# 学习率：0.0001
# 数据：100
# 数据：110
#  1/20 [>.............................] - ETA: 6:05 - loss: 22.4665 - loss_rpn_match: 10.7132 - loss_rpn_bbox: 11.7533数据：120
#  2/20 [==>...........................] - ETA: 4:48 - loss: 16.3319 - loss_rpn_match: 7.4276 - loss_rpn_bbox: 8.9044  数据：130
#  3/20 [===>..........................] - ETA: 4:11 - loss: 15.1120 - loss_rpn_match: 7.3280 - loss_rpn_bbox: 7.7839数据：140
#  4/20 [=====>........................] - ETA: 3:44 - loss: 13.6802 - loss_rpn_match: 6.5908 - loss_rpn_bbox: 7.0894数据：150
#  5/20 [======>.......................] - ETA: 3:24 - loss: 12.5037 - loss_rpn_match: 5.8420 - loss_rpn_bbox: 6.6617数据：160
#  6/20 [========>.....................] - ETA: 3:04 - loss: 11.6204 - loss_rpn_match: 5.3390 - loss_rpn_bbox: 6.2814数据：170
#  7/20 [=========>....................] - ETA: 2:46 - loss: 10.8243 - loss_rpn_match: 4.9492 - loss_rpn_bbox: 5.8751数据：180
#  8/20 [===========>..................] - ETA: 2:32 - loss: 10.0245 - loss_rpn_match: 4.5435 - loss_rpn_bbox: 5.4810数据：190
#  9/20 [============>.................] - ETA: 2:17 - loss: 9.3252 - loss_rpn_match: 4.2082 - loss_rpn_bbox: 5.1170 数据：200
# 10/20 [==============>...............] - ETA: 2:03 - loss: 8.7235 - loss_rpn_match: 3.9209 - loss_rpn_bbox: 4.8026数据：210
# 11/20 [===============>..............] - ETA: 1:49 - loss: 8.2721 - loss_rpn_match: 3.7043 - loss_rpn_bbox: 4.5679数据：220
# 12/20 [=================>............] - ETA: 1:36 - loss: 7.8388 - loss_rpn_match: 3.5032 - loss_rpn_bbox: 4.3356数据：230
# 13/20 [==================>...........] - ETA: 1:23 - loss: 7.4824 - loss_rpn_match: 3.3337 - loss_rpn_bbox: 4.1487数据：240
# 14/20 [====================>.........] - ETA: 1:11 - loss: 7.1172 - loss_rpn_match: 3.1724 - loss_rpn_bbox: 3.9448数据：250
# 15/20 [=====================>........] - ETA: 59s - loss: 6.7840 - loss_rpn_match: 3.0179 - loss_rpn_bbox: 3.7661 数据：260
# 16/20 [=======================>......] - ETA: 46s - loss: 6.4981 - loss_rpn_match: 2.8913 - loss_rpn_bbox: 3.6069数据：270
# 17/20 [========================>.....] - ETA: 34s - loss: 6.2452 - loss_rpn_match: 2.7788 - loss_rpn_bbox: 3.4664数据：280
# 18/20 [==========================>...] - ETA: 23s - loss: 6.0243 - loss_rpn_match: 2.6863 - loss_rpn_bbox: 3.3380数据：290
# 19/20 [===========================>..] - ETA: 11s - loss: 5.8104 - loss_rpn_match: 2.5896 - loss_rpn_bbox: 3.2208数据：300
# 20/20 [==============================] - 230s 11s/step - loss: 5.6232 - loss_rpn_match: 2.5046 - loss_rpn_bbox: 3.1186
# Epoch 2/20
# 学习率：0.0001
# 数据：310
#  1/20 [>.............................] - ETA: 3:20 - loss: 2.0345 - loss_rpn_match: 0.8394 - loss_rpn_bbox: 1.1951数据：320
#  2/20 [==>...........................] - ETA: 3:08 - loss: 1.8638 - loss_rpn_match: 0.7791 - loss_rpn_bbox: 1.0847数据：330
#  3/20 [===>..........................] - ETA: 2:58 - loss: 1.8484 - loss_rpn_match: 0.8069 - loss_rpn_bbox: 1.0415数据：340
#  4/20 [=====>........................] - ETA: 2:48 - loss: 1.7980 - loss_rpn_match: 0.7981 - loss_rpn_bbox: 0.9998数据：350
#  5/20 [======>.......................] - ETA: 2:37 - loss: 1.7919 - loss_rpn_match: 0.7899 - loss_rpn_bbox: 1.0019数据：360
#  6/20 [========>.....................] - ETA: 2:27 - loss: 1.7916 - loss_rpn_match: 0.7720 - loss_rpn_bbox: 1.0196数据：370
#  7/20 [=========>....................] - ETA: 2:17 - loss: 1.7695 - loss_rpn_match: 0.7687 - loss_rpn_bbox: 1.0008数据：380
#  8/20 [===========>..................] - ETA: 2:07 - loss: 1.7401 - loss_rpn_match: 0.7504 - loss_rpn_bbox: 0.9897数据：390
#  9/20 [============>.................] - ETA: 1:56 - loss: 1.7221 - loss_rpn_match: 0.7438 - loss_rpn_bbox: 0.9783数据：400
# 10/20 [==============>...............] - ETA: 1:45 - loss: 1.7223 - loss_rpn_match: 0.7407 - loss_rpn_bbox: 0.9817数据：410
# 11/20 [===============>..............] - ETA: 1:35 - loss: 1.7279 - loss_rpn_match: 0.7556 - loss_rpn_bbox: 0.9723数据：420
# 12/20 [=================>............] - ETA: 1:24 - loss: 1.7158 - loss_rpn_match: 0.7535 - loss_rpn_bbox: 0.9624数据：430
# 13/20 [==================>...........] - ETA: 1:13 - loss: 1.6994 - loss_rpn_match: 0.7447 - loss_rpn_bbox: 0.9546数据：440
# 14/20 [====================>.........] - ETA: 1:03 - loss: 1.6938 - loss_rpn_match: 0.7374 - loss_rpn_bbox: 0.9564数据：450
# 15/20 [=====================>........] - ETA: 52s - loss: 1.6726 - loss_rpn_match: 0.7267 - loss_rpn_bbox: 0.9459 数据：460
# 16/20 [=======================>......] - ETA: 42s - loss: 1.6706 - loss_rpn_match: 0.7256 - loss_rpn_bbox: 0.9450数据：470
# 17/20 [========================>.....] - ETA: 31s - loss: 1.6580 - loss_rpn_match: 0.7190 - loss_rpn_bbox: 0.9390数据：480
# 18/20 [==========================>...] - ETA: 21s - loss: 1.6511 - loss_rpn_match: 0.7195 - loss_rpn_bbox: 0.9317数据：490
# 19/20 [===========================>..] - ETA: 10s - loss: 1.6546 - loss_rpn_match: 0.7217 - loss_rpn_bbox: 0.9329数据：500
# 20/20 [==============================] - 211s 11s/step - loss: 1.6473 - loss_rpn_match: 0.7215 - loss_rpn_bbox: 0.9258
# Epoch 3/20
# 学习率：0.0001
# 数据：510
#  1/20 [>.............................] - ETA: 3:22 - loss: 1.5350 - loss_rpn_match: 0.6221 - loss_rpn_bbox: 0.9129数据：520
#  2/20 [==>...........................] - ETA: 3:10 - loss: 1.4887 - loss_rpn_match: 0.6613 - loss_rpn_bbox: 0.8274数据：530
#  3/20 [===>..........................] - ETA: 2:59 - loss: 1.4785 - loss_rpn_match: 0.6315 - loss_rpn_bbox: 0.8470数据：540
#  4/20 [=====>........................] - ETA: 2:48 - loss: 1.4818 - loss_rpn_match: 0.6521 - loss_rpn_bbox: 0.8297数据：550
#  5/20 [======>.......................] - ETA: 2:37 - loss: 1.4703 - loss_rpn_match: 0.6555 - loss_rpn_bbox: 0.8148数据：560
#  6/20 [========>.....................] - ETA: 2:27 - loss: 1.4735 - loss_rpn_match: 0.6656 - loss_rpn_bbox: 0.8079数据：570
#  7/20 [=========>....................] - ETA: 2:16 - loss: 1.4749 - loss_rpn_match: 0.6665 - loss_rpn_bbox: 0.8084数据：580
#  8/20 [===========>..................] - ETA: 2:06 - loss: 1.4857 - loss_rpn_match: 0.6687 - loss_rpn_bbox: 0.8170数据：590
#  9/20 [============>.................] - ETA: 1:55 - loss: 1.4861 - loss_rpn_match: 0.6697 - loss_rpn_bbox: 0.8164数据：600
# 10/20 [==============>...............] - ETA: 1:45 - loss: 1.4898 - loss_rpn_match: 0.6696 - loss_rpn_bbox: 0.8201数据：610
# 11/20 [===============>..............] - ETA: 1:34 - loss: 1.4863 - loss_rpn_match: 0.6708 - loss_rpn_bbox: 0.8155数据：620
# 12/20 [=================>............] - ETA: 1:24 - loss: 1.4811 - loss_rpn_match: 0.6709 - loss_rpn_bbox: 0.8103数据：630
# 13/20 [==================>...........] - ETA: 1:13 - loss: 1.4736 - loss_rpn_match: 0.6715 - loss_rpn_bbox: 0.8021数据：640
# 14/20 [====================>.........] - ETA: 1:03 - loss: 1.4671 - loss_rpn_match: 0.6707 - loss_rpn_bbox: 0.7964数据：650
# 15/20 [=====================>........] - ETA: 52s - loss: 1.4737 - loss_rpn_match: 0.6669 - loss_rpn_bbox: 0.8068 数据：660
# 16/20 [=======================>......] - ETA: 42s - loss: 1.4704 - loss_rpn_match: 0.6690 - loss_rpn_bbox: 0.8014数据：670
# 17/20 [========================>.....] - ETA: 31s - loss: 1.4675 - loss_rpn_match: 0.6712 - loss_rpn_bbox: 0.7963数据：680
# 18/20 [==========================>...] - ETA: 21s - loss: 1.4732 - loss_rpn_match: 0.6716 - loss_rpn_bbox: 0.8016数据：690
# 19/20 [===========================>..] - ETA: 10s - loss: 1.4745 - loss_rpn_match: 0.6727 - loss_rpn_bbox: 0.8018数据：700
# 20/20 [==============================] - 212s 11s/step - loss: 1.4689 - loss_rpn_match: 0.6691 - loss_rpn_bbox: 0.7998
# Epoch 4/20
# 学习率：0.0001
# 数据：710
#  1/20 [>.............................] - ETA: 3:16 - loss: 1.4715 - loss_rpn_match: 0.6306 - loss_rpn_bbox: 0.8409数据：720
#  2/20 [==>...........................] - ETA: 3:07 - loss: 1.4847 - loss_rpn_match: 0.6620 - loss_rpn_bbox: 0.8228数据：730
#  3/20 [===>..........................] - ETA: 2:58 - loss: 1.4508 - loss_rpn_match: 0.6441 - loss_rpn_bbox: 0.8067数据：740
#  4/20 [=====>........................] - ETA: 2:48 - loss: 1.4299 - loss_rpn_match: 0.6452 - loss_rpn_bbox: 0.7847数据：750
#  5/20 [======>.......................] - ETA: 2:37 - loss: 1.4440 - loss_rpn_match: 0.6549 - loss_rpn_bbox: 0.7891数据：760
#  6/20 [========>.....................] - ETA: 2:26 - loss: 1.4516 - loss_rpn_match: 0.6536 - loss_rpn_bbox: 0.7980数据：770
#  7/20 [=========>....................] - ETA: 2:16 - loss: 1.4621 - loss_rpn_match: 0.6647 - loss_rpn_bbox: 0.7974数据：780
#  8/20 [===========>..................] - ETA: 2:06 - loss: 1.4619 - loss_rpn_match: 0.6678 - loss_rpn_bbox: 0.7941数据：790
#  9/20 [============>.................] - ETA: 1:55 - loss: 1.4706 - loss_rpn_match: 0.6711 - loss_rpn_bbox: 0.7994数据：800
# 10/20 [==============>...............] - ETA: 1:45 - loss: 1.4709 - loss_rpn_match: 0.6676 - loss_rpn_bbox: 0.8033数据：810
# 11/20 [===============>..............] - ETA: 1:34 - loss: 1.4724 - loss_rpn_match: 0.6700 - loss_rpn_bbox: 0.8024数据：820
# 12/20 [=================>............] - ETA: 1:24 - loss: 1.4597 - loss_rpn_match: 0.6670 - loss_rpn_bbox: 0.7927数据：830
# 13/20 [==================>...........] - ETA: 1:14 - loss: 1.4578 - loss_rpn_match: 0.6649 - loss_rpn_bbox: 0.7929数据：840
# 14/20 [====================>.........] - ETA: 1:03 - loss: 1.4588 - loss_rpn_match: 0.6641 - loss_rpn_bbox: 0.7947数据：850
# 15/20 [=====================>........] - ETA: 52s - loss: 1.4551 - loss_rpn_match: 0.6617 - loss_rpn_bbox: 0.7934 数据：860
# 16/20 [=======================>......] - ETA: 42s - loss: 1.4440 - loss_rpn_match: 0.6577 - loss_rpn_bbox: 0.7863数据：870
# 17/20 [========================>.....] - ETA: 31s - loss: 1.4407 - loss_rpn_match: 0.6535 - loss_rpn_bbox: 0.7872数据：880
# 18/20 [==========================>...] - ETA: 21s - loss: 1.4413 - loss_rpn_match: 0.6538 - loss_rpn_bbox: 0.7875数据：890
# 19/20 [===========================>..] - ETA: 10s - loss: 1.4416 - loss_rpn_match: 0.6550 - loss_rpn_bbox: 0.7867数据：900
# 20/20 [==============================] - 211s 11s/step - loss: 1.4399 - loss_rpn_match: 0.6560 - loss_rpn_bbox: 0.7839
# Epoch 5/20
# 学习率：8e-05
# 数据：910
#  1/20 [>.............................] - ETA: 3:30 - loss: 1.4174 - loss_rpn_match: 0.6264 - loss_rpn_bbox: 0.7911数据：920
#  2/20 [==>...........................] - ETA: 3:22 - loss: 1.3870 - loss_rpn_match: 0.6096 - loss_rpn_bbox: 0.7774数据：930
#  3/20 [===>..........................] - ETA: 3:08 - loss: 1.3774 - loss_rpn_match: 0.6168 - loss_rpn_bbox: 0.7606数据：940
#  4/20 [=====>........................] - ETA: 2:55 - loss: 1.3695 - loss_rpn_match: 0.6221 - loss_rpn_bbox: 0.7474数据：950
#  5/20 [======>.......................] - ETA: 2:43 - loss: 1.3728 - loss_rpn_match: 0.6094 - loss_rpn_bbox: 0.7634数据：960
#  6/20 [========>.....................] - ETA: 2:32 - loss: 1.3832 - loss_rpn_match: 0.6211 - loss_rpn_bbox: 0.7620数据：970
#  7/20 [=========>....................] - ETA: 2:21 - loss: 1.3948 - loss_rpn_match: 0.6241 - loss_rpn_bbox: 0.7707数据：980
#  8/20 [===========>..................] - ETA: 2:09 - loss: 1.4008 - loss_rpn_match: 0.6249 - loss_rpn_bbox: 0.7760数据：990
#  9/20 [============>.................] - ETA: 1:58 - loss: 1.4072 - loss_rpn_match: 0.6260 - loss_rpn_bbox: 0.7812数据：1000
# 10/20 [==============>...............] - ETA: 1:48 - loss: 1.4132 - loss_rpn_match: 0.6252 - loss_rpn_bbox: 0.7879数据：1010
# 11/20 [===============>..............] - ETA: 1:36 - loss: 1.4262 - loss_rpn_match: 0.6327 - loss_rpn_bbox: 0.7935数据：1020
# 12/20 [=================>............] - ETA: 1:26 - loss: 1.4364 - loss_rpn_match: 0.6410 - loss_rpn_bbox: 0.7954数据：1030
# 13/20 [==================>...........] - ETA: 1:15 - loss: 1.4336 - loss_rpn_match: 0.6422 - loss_rpn_bbox: 0.7914数据：1040
# 14/20 [====================>.........] - ETA: 1:04 - loss: 1.4284 - loss_rpn_match: 0.6433 - loss_rpn_bbox: 0.7851数据：1050
# 15/20 [=====================>........] - ETA: 53s - loss: 1.4274 - loss_rpn_match: 0.6460 - loss_rpn_bbox: 0.7814 数据：1060
# 16/20 [=======================>......] - ETA: 42s - loss: 1.4235 - loss_rpn_match: 0.6425 - loss_rpn_bbox: 0.7810数据：1070
# 17/20 [========================>.....] - ETA: 32s - loss: 1.4269 - loss_rpn_match: 0.6467 - loss_rpn_bbox: 0.7803数据：1080
# 18/20 [==========================>...] - ETA: 21s - loss: 1.4244 - loss_rpn_match: 0.6470 - loss_rpn_bbox: 0.7774数据：1090
# 19/20 [===========================>..] - ETA: 10s - loss: 1.4234 - loss_rpn_match: 0.6471 - loss_rpn_bbox: 0.7763数据：1100
# 20/20 [==============================] - 214s 11s/step - loss: 1.4245 - loss_rpn_match: 0.6460 - loss_rpn_bbox: 0.7786
# Epoch 6/20
# 学习率：8e-05
# 数据：1110
#  1/20 [>.............................] - ETA: 3:19 - loss: 1.3169 - loss_rpn_match: 0.6409 - loss_rpn_bbox: 0.6760数据：1120
#  2/20 [==>...........................] - ETA: 3:09 - loss: 1.3258 - loss_rpn_match: 0.6538 - loss_rpn_bbox: 0.6721数据：1130
#  3/20 [===>..........................] - ETA: 2:59 - loss: 1.3498 - loss_rpn_match: 0.6481 - loss_rpn_bbox: 0.7017数据：1140
#  4/20 [=====>........................] - ETA: 2:48 - loss: 1.3598 - loss_rpn_match: 0.6528 - loss_rpn_bbox: 0.7070数据：1150
#  5/20 [======>.......................] - ETA: 2:38 - loss: 1.3701 - loss_rpn_match: 0.6509 - loss_rpn_bbox: 0.7191数据：1160
#  6/20 [========>.....................] - ETA: 2:30 - loss: 1.3781 - loss_rpn_match: 0.6615 - loss_rpn_bbox: 0.7166数据：1170
#  7/20 [=========>....................] - ETA: 2:20 - loss: 1.3722 - loss_rpn_match: 0.6591 - loss_rpn_bbox: 0.7130数据：1180
#  8/20 [===========>..................] - ETA: 2:09 - loss: 1.3663 - loss_rpn_match: 0.6610 - loss_rpn_bbox: 0.7053数据：1190
#  9/20 [============>.................] - ETA: 1:58 - loss: 1.3661 - loss_rpn_match: 0.6576 - loss_rpn_bbox: 0.7085数据：1200
# 10/20 [==============>...............] - ETA: 1:48 - loss: 1.3682 - loss_rpn_match: 0.6599 - loss_rpn_bbox: 0.7083数据：1210
# 11/20 [===============>..............] - ETA: 1:38 - loss: 1.3732 - loss_rpn_match: 0.6583 - loss_rpn_bbox: 0.7149数据：1220
# 12/20 [=================>............] - ETA: 1:28 - loss: 1.3725 - loss_rpn_match: 0.6571 - loss_rpn_bbox: 0.7154数据：1230
# 13/20 [==================>...........] - ETA: 1:17 - loss: 1.3677 - loss_rpn_match: 0.6569 - loss_rpn_bbox: 0.7108数据：1240
# 14/20 [====================>.........] - ETA: 1:06 - loss: 1.3708 - loss_rpn_match: 0.6591 - loss_rpn_bbox: 0.7117数据：1250
# 15/20 [=====================>........] - ETA: 55s - loss: 1.3734 - loss_rpn_match: 0.6599 - loss_rpn_bbox: 0.7134 数据：1260
# 16/20 [=======================>......] - ETA: 44s - loss: 1.3773 - loss_rpn_match: 0.6607 - loss_rpn_bbox: 0.7166数据：1270
# 17/20 [========================>.....] - ETA: 33s - loss: 1.3800 - loss_rpn_match: 0.6594 - loss_rpn_bbox: 0.7206数据：1280
# 18/20 [==========================>...] - ETA: 22s - loss: 1.3785 - loss_rpn_match: 0.6566 - loss_rpn_bbox: 0.7219数据：1290
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3853 - loss_rpn_match: 0.6549 - loss_rpn_bbox: 0.7303数据：1300
# 20/20 [==============================] - 227s 11s/step - loss: 1.3873 - loss_rpn_match: 0.6539 - loss_rpn_bbox: 0.7334
# Epoch 7/20
# 学习率：8e-05
# 数据：1310
#  1/20 [>.............................] - ETA: 3:51 - loss: 1.3137 - loss_rpn_match: 0.6444 - loss_rpn_bbox: 0.6693数据：1320
#  2/20 [==>...........................] - ETA: 3:40 - loss: 1.3627 - loss_rpn_match: 0.6496 - loss_rpn_bbox: 0.7132数据：1330
#  3/20 [===>..........................] - ETA: 3:25 - loss: 1.3717 - loss_rpn_match: 0.6636 - loss_rpn_bbox: 0.7081数据：1340
#  4/20 [=====>........................] - ETA: 3:10 - loss: 1.3607 - loss_rpn_match: 0.6626 - loss_rpn_bbox: 0.6981数据：1350
#  5/20 [======>.......................] - ETA: 2:58 - loss: 1.3836 - loss_rpn_match: 0.6713 - loss_rpn_bbox: 0.7123数据：1360
#  6/20 [========>.....................] - ETA: 2:46 - loss: 1.3813 - loss_rpn_match: 0.6687 - loss_rpn_bbox: 0.7126数据：1370
#  7/20 [=========>....................] - ETA: 2:33 - loss: 1.3927 - loss_rpn_match: 0.6654 - loss_rpn_bbox: 0.7273数据：1380
#  8/20 [===========>..................] - ETA: 2:20 - loss: 1.3985 - loss_rpn_match: 0.6635 - loss_rpn_bbox: 0.7349数据：1390
#  9/20 [============>.................] - ETA: 2:09 - loss: 1.4028 - loss_rpn_match: 0.6682 - loss_rpn_bbox: 0.7346数据：1400
# 10/20 [==============>...............] - ETA: 1:58 - loss: 1.4023 - loss_rpn_match: 0.6692 - loss_rpn_bbox: 0.7331数据：1410
# 11/20 [===============>..............] - ETA: 1:46 - loss: 1.4067 - loss_rpn_match: 0.6703 - loss_rpn_bbox: 0.7364数据：1420
# 12/20 [=================>............] - ETA: 1:35 - loss: 1.4010 - loss_rpn_match: 0.6644 - loss_rpn_bbox: 0.7366数据：1430
# 13/20 [==================>...........] - ETA: 1:22 - loss: 1.3956 - loss_rpn_match: 0.6590 - loss_rpn_bbox: 0.7367数据：1440
# 14/20 [====================>.........] - ETA: 1:10 - loss: 1.4034 - loss_rpn_match: 0.6592 - loss_rpn_bbox: 0.7442数据：1450
# 15/20 [=====================>........] - ETA: 58s - loss: 1.4019 - loss_rpn_match: 0.6578 - loss_rpn_bbox: 0.7441 数据：1460
# 16/20 [=======================>......] - ETA: 46s - loss: 1.3994 - loss_rpn_match: 0.6570 - loss_rpn_bbox: 0.7424数据：1470
# 17/20 [========================>.....] - ETA: 35s - loss: 1.3987 - loss_rpn_match: 0.6559 - loss_rpn_bbox: 0.7428数据：1480
# 18/20 [==========================>...] - ETA: 23s - loss: 1.3948 - loss_rpn_match: 0.6533 - loss_rpn_bbox: 0.7415数据：1490
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3896 - loss_rpn_match: 0.6530 - loss_rpn_bbox: 0.7367数据：1500
# 20/20 [==============================] - 232s 12s/step - loss: 1.3892 - loss_rpn_match: 0.6525 - loss_rpn_bbox: 0.7368
# Epoch 8/20
# 学习率：8e-05
# 数据：1510
#  1/20 [>.............................] - ETA: 3:32 - loss: 1.4459 - loss_rpn_match: 0.6480 - loss_rpn_bbox: 0.7979数据：1520
#  2/20 [==>...........................] - ETA: 3:17 - loss: 1.4055 - loss_rpn_match: 0.6664 - loss_rpn_bbox: 0.7391数据：1530
#  3/20 [===>..........................] - ETA: 3:03 - loss: 1.3795 - loss_rpn_match: 0.6545 - loss_rpn_bbox: 0.7250数据：1540
#  4/20 [=====>........................] - ETA: 2:51 - loss: 1.4089 - loss_rpn_match: 0.6549 - loss_rpn_bbox: 0.7540数据：1550
#  5/20 [======>.......................] - ETA: 2:42 - loss: 1.4015 - loss_rpn_match: 0.6501 - loss_rpn_bbox: 0.7514数据：1560
#  6/20 [========>.....................] - ETA: 2:32 - loss: 1.3889 - loss_rpn_match: 0.6520 - loss_rpn_bbox: 0.7369数据：1570
#  7/20 [=========>....................] - ETA: 2:21 - loss: 1.3752 - loss_rpn_match: 0.6509 - loss_rpn_bbox: 0.7242数据：1580
#  8/20 [===========>..................] - ETA: 2:12 - loss: 1.3837 - loss_rpn_match: 0.6501 - loss_rpn_bbox: 0.7337数据：1590
#  9/20 [============>.................] - ETA: 2:01 - loss: 1.3847 - loss_rpn_match: 0.6486 - loss_rpn_bbox: 0.7362数据：1600
# 10/20 [==============>...............] - ETA: 1:50 - loss: 1.3793 - loss_rpn_match: 0.6441 - loss_rpn_bbox: 0.7352数据：1610
# 11/20 [===============>..............] - ETA: 1:40 - loss: 1.3874 - loss_rpn_match: 0.6481 - loss_rpn_bbox: 0.7393数据：1620
# 12/20 [=================>............] - ETA: 1:29 - loss: 1.3910 - loss_rpn_match: 0.6471 - loss_rpn_bbox: 0.7439数据：1630
# 13/20 [==================>...........] - ETA: 1:18 - loss: 1.3939 - loss_rpn_match: 0.6463 - loss_rpn_bbox: 0.7475数据：1640
# 14/20 [====================>.........] - ETA: 1:07 - loss: 1.3863 - loss_rpn_match: 0.6434 - loss_rpn_bbox: 0.7429数据：1650
# 15/20 [=====================>........] - ETA: 56s - loss: 1.3876 - loss_rpn_match: 0.6441 - loss_rpn_bbox: 0.7435 数据：1660
# 16/20 [=======================>......] - ETA: 44s - loss: 1.3955 - loss_rpn_match: 0.6472 - loss_rpn_bbox: 0.7482数据：1670
# 17/20 [========================>.....] - ETA: 33s - loss: 1.3991 - loss_rpn_match: 0.6482 - loss_rpn_bbox: 0.7509数据：1680
# 18/20 [==========================>...] - ETA: 22s - loss: 1.3992 - loss_rpn_match: 0.6469 - loss_rpn_bbox: 0.7524数据：1690
# 19/20 [===========================>..] - ETA: 11s - loss: 1.4057 - loss_rpn_match: 0.6470 - loss_rpn_bbox: 0.7587数据：1700
# 20/20 [==============================] - 223s 11s/step - loss: 1.4069 - loss_rpn_match: 0.6477 - loss_rpn_bbox: 0.7592
# Epoch 9/20
# 学习率：8e-05
# 数据：1710
#  1/20 [>.............................] - ETA: 3:38 - loss: 1.3686 - loss_rpn_match: 0.6195 - loss_rpn_bbox: 0.7490数据：1720
#  2/20 [==>...........................] - ETA: 3:26 - loss: 1.3694 - loss_rpn_match: 0.6293 - loss_rpn_bbox: 0.7401数据：1730
#  3/20 [===>..........................] - ETA: 3:15 - loss: 1.4322 - loss_rpn_match: 0.6436 - loss_rpn_bbox: 0.7886数据：1740
#  4/20 [=====>........................] - ETA: 3:03 - loss: 1.4207 - loss_rpn_match: 0.6400 - loss_rpn_bbox: 0.7807数据：1750
#  5/20 [======>.......................] - ETA: 2:53 - loss: 1.4247 - loss_rpn_match: 0.6423 - loss_rpn_bbox: 0.7825数据：1760
#  6/20 [========>.....................] - ETA: 2:41 - loss: 1.4212 - loss_rpn_match: 0.6490 - loss_rpn_bbox: 0.7723数据：1770
#  7/20 [=========>....................] - ETA: 2:29 - loss: 1.4266 - loss_rpn_match: 0.6459 - loss_rpn_bbox: 0.7807数据：1780
#  8/20 [===========>..................] - ETA: 2:18 - loss: 1.4207 - loss_rpn_match: 0.6470 - loss_rpn_bbox: 0.7737数据：1790
#  9/20 [============>.................] - ETA: 2:07 - loss: 1.4185 - loss_rpn_match: 0.6464 - loss_rpn_bbox: 0.7721数据：1800
# 10/20 [==============>...............] - ETA: 1:56 - loss: 1.4183 - loss_rpn_match: 0.6465 - loss_rpn_bbox: 0.7719数据：1810
# 11/20 [===============>..............] - ETA: 1:44 - loss: 1.4409 - loss_rpn_match: 0.6477 - loss_rpn_bbox: 0.7932数据：1820
# 12/20 [=================>............] - ETA: 1:32 - loss: 1.4396 - loss_rpn_match: 0.6524 - loss_rpn_bbox: 0.7872数据：1830
# 13/20 [==================>...........] - ETA: 1:20 - loss: 1.4299 - loss_rpn_match: 0.6478 - loss_rpn_bbox: 0.7821数据：1840
# 14/20 [====================>.........] - ETA: 1:08 - loss: 1.4241 - loss_rpn_match: 0.6445 - loss_rpn_bbox: 0.7795数据：1850
# 15/20 [=====================>........] - ETA: 57s - loss: 1.4285 - loss_rpn_match: 0.6459 - loss_rpn_bbox: 0.7826 数据：1860
# 16/20 [=======================>......] - ETA: 45s - loss: 1.4252 - loss_rpn_match: 0.6467 - loss_rpn_bbox: 0.7785数据：1870
# 17/20 [========================>.....] - ETA: 34s - loss: 1.4266 - loss_rpn_match: 0.6442 - loss_rpn_bbox: 0.7823数据：1880
# 18/20 [==========================>...] - ETA: 22s - loss: 1.4264 - loss_rpn_match: 0.6430 - loss_rpn_bbox: 0.7834数据：1890
# 19/20 [===========================>..] - ETA: 11s - loss: 1.4285 - loss_rpn_match: 0.6437 - loss_rpn_bbox: 0.7848数据：1900
# 20/20 [==============================] - 228s 11s/step - loss: 1.4245 - loss_rpn_match: 0.6419 - loss_rpn_bbox: 0.7827
# Epoch 10/20
# 学习率：6.400000000000001e-05
# 数据：1910
#  1/20 [>.............................] - ETA: 3:29 - loss: 1.4516 - loss_rpn_match: 0.6528 - loss_rpn_bbox: 0.7987数据：1920
#  2/20 [==>...........................] - ETA: 3:21 - loss: 1.4266 - loss_rpn_match: 0.6435 - loss_rpn_bbox: 0.7831数据：1930
#  3/20 [===>..........................] - ETA: 3:08 - loss: 1.4143 - loss_rpn_match: 0.6455 - loss_rpn_bbox: 0.7688数据：1940
#  4/20 [=====>........................] - ETA: 2:57 - loss: 1.4304 - loss_rpn_match: 0.6346 - loss_rpn_bbox: 0.7959数据：1950
#  5/20 [======>.......................] - ETA: 2:46 - loss: 1.4218 - loss_rpn_match: 0.6409 - loss_rpn_bbox: 0.7810数据：1960
#  6/20 [========>.....................] - ETA: 2:35 - loss: 1.4095 - loss_rpn_match: 0.6349 - loss_rpn_bbox: 0.7746数据：1970
#  7/20 [=========>....................] - ETA: 2:24 - loss: 1.3977 - loss_rpn_match: 0.6312 - loss_rpn_bbox: 0.7664数据：1980
#  8/20 [===========>..................] - ETA: 2:14 - loss: 1.3940 - loss_rpn_match: 0.6294 - loss_rpn_bbox: 0.7646数据：1990
#  9/20 [============>.................] - ETA: 2:04 - loss: 1.3947 - loss_rpn_match: 0.6264 - loss_rpn_bbox: 0.7683数据：2000
# 10/20 [==============>...............] - ETA: 1:53 - loss: 1.3931 - loss_rpn_match: 0.6291 - loss_rpn_bbox: 0.7639数据：2010
# 11/20 [===============>..............] - ETA: 1:43 - loss: 1.3932 - loss_rpn_match: 0.6329 - loss_rpn_bbox: 0.7603数据：2020
# 12/20 [=================>............] - ETA: 1:31 - loss: 1.3919 - loss_rpn_match: 0.6345 - loss_rpn_bbox: 0.7574数据：2030
# 13/20 [==================>...........] - ETA: 1:20 - loss: 1.4003 - loss_rpn_match: 0.6353 - loss_rpn_bbox: 0.7650数据：2040
# 14/20 [====================>.........] - ETA: 1:09 - loss: 1.3979 - loss_rpn_match: 0.6358 - loss_rpn_bbox: 0.7621数据：2050
# 15/20 [=====================>........] - ETA: 57s - loss: 1.4001 - loss_rpn_match: 0.6350 - loss_rpn_bbox: 0.7651 数据：2060
# 16/20 [=======================>......] - ETA: 46s - loss: 1.3968 - loss_rpn_match: 0.6335 - loss_rpn_bbox: 0.7633数据：2070
# 17/20 [========================>.....] - ETA: 34s - loss: 1.3951 - loss_rpn_match: 0.6328 - loss_rpn_bbox: 0.7623数据：2080
# 18/20 [==========================>...] - ETA: 23s - loss: 1.3940 - loss_rpn_match: 0.6318 - loss_rpn_bbox: 0.7622数据：2090
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3949 - loss_rpn_match: 0.6321 - loss_rpn_bbox: 0.7628数据：2100
# 20/20 [==============================] - 232s 12s/step - loss: 1.4005 - loss_rpn_match: 0.6343 - loss_rpn_bbox: 0.7662
# Epoch 11/20
# 学习率：6.400000000000001e-05
# 数据：2110
#  1/20 [>.............................] - ETA: 3:40 - loss: 1.4067 - loss_rpn_match: 0.5591 - loss_rpn_bbox: 0.8475数据：2120
#  2/20 [==>...........................] - ETA: 3:27 - loss: 1.3850 - loss_rpn_match: 0.6170 - loss_rpn_bbox: 0.7680数据：2130
#  3/20 [===>..........................] - ETA: 3:18 - loss: 1.4200 - loss_rpn_match: 0.6360 - loss_rpn_bbox: 0.7841数据：2140
#  4/20 [=====>........................] - ETA: 3:06 - loss: 1.4108 - loss_rpn_match: 0.6412 - loss_rpn_bbox: 0.7696数据：2150
#  5/20 [======>.......................] - ETA: 2:54 - loss: 1.3928 - loss_rpn_match: 0.6523 - loss_rpn_bbox: 0.7405数据：2160
#  6/20 [========>.....................] - ETA: 2:42 - loss: 1.3772 - loss_rpn_match: 0.6462 - loss_rpn_bbox: 0.7310数据：2170
#  7/20 [=========>....................] - ETA: 2:31 - loss: 1.3695 - loss_rpn_match: 0.6465 - loss_rpn_bbox: 0.7230数据：2180
#  8/20 [===========>..................] - ETA: 2:19 - loss: 1.3606 - loss_rpn_match: 0.6444 - loss_rpn_bbox: 0.7162数据：2190
#  9/20 [============>.................] - ETA: 2:09 - loss: 1.3664 - loss_rpn_match: 0.6425 - loss_rpn_bbox: 0.7239数据：2200
# 10/20 [==============>...............] - ETA: 1:57 - loss: 1.3600 - loss_rpn_match: 0.6416 - loss_rpn_bbox: 0.7184数据：2210
# 11/20 [===============>..............] - ETA: 1:46 - loss: 1.3675 - loss_rpn_match: 0.6448 - loss_rpn_bbox: 0.7227数据：2220
# 12/20 [=================>............] - ETA: 1:34 - loss: 1.3687 - loss_rpn_match: 0.6466 - loss_rpn_bbox: 0.7221数据：2230
# 13/20 [==================>...........] - ETA: 1:22 - loss: 1.3712 - loss_rpn_match: 0.6471 - loss_rpn_bbox: 0.7241数据：2240
# 14/20 [====================>.........] - ETA: 1:12 - loss: 1.3721 - loss_rpn_match: 0.6490 - loss_rpn_bbox: 0.7231数据：2250
# 15/20 [=====================>........] - ETA: 1:04 - loss: 1.3722 - loss_rpn_match: 0.6496 - loss_rpn_bbox: 0.7226数据：2260
# 16/20 [=======================>......] - ETA: 52s - loss: 1.3683 - loss_rpn_match: 0.6473 - loss_rpn_bbox: 0.7211 数据：2270
# 17/20 [========================>.....] - ETA: 38s - loss: 1.3695 - loss_rpn_match: 0.6466 - loss_rpn_bbox: 0.7230数据：2280
# 18/20 [==========================>...] - ETA: 25s - loss: 1.3689 - loss_rpn_match: 0.6477 - loss_rpn_bbox: 0.7212数据：2290
# 19/20 [===========================>..] - ETA: 12s - loss: 1.3680 - loss_rpn_match: 0.6480 - loss_rpn_bbox: 0.7200数据：2300
# 20/20 [==============================] - 257s 13s/step - loss: 1.3698 - loss_rpn_match: 0.6473 - loss_rpn_bbox: 0.7225
# Epoch 12/20
# 学习率：6.400000000000001e-05
# 数据：2310
#  1/20 [>.............................] - ETA: 3:51 - loss: 1.4670 - loss_rpn_match: 0.7531 - loss_rpn_bbox: 0.7139数据：2320
#  2/20 [==>...........................] - ETA: 3:39 - loss: 1.4451 - loss_rpn_match: 0.7055 - loss_rpn_bbox: 0.7396数据：2330
#  3/20 [===>..........................] - ETA: 3:27 - loss: 1.4547 - loss_rpn_match: 0.6817 - loss_rpn_bbox: 0.7730数据：2340
#  4/20 [=====>........................] - ETA: 3:14 - loss: 1.4160 - loss_rpn_match: 0.6687 - loss_rpn_bbox: 0.7473数据：2350
#  5/20 [======>.......................] - ETA: 3:03 - loss: 1.4152 - loss_rpn_match: 0.6618 - loss_rpn_bbox: 0.7533数据：2360
#  6/20 [========>.....................] - ETA: 2:53 - loss: 1.4037 - loss_rpn_match: 0.6544 - loss_rpn_bbox: 0.7494数据：2370
#  7/20 [=========>....................] - ETA: 2:41 - loss: 1.4034 - loss_rpn_match: 0.6545 - loss_rpn_bbox: 0.7489数据：2380
#  8/20 [===========>..................] - ETA: 2:29 - loss: 1.4153 - loss_rpn_match: 0.6565 - loss_rpn_bbox: 0.7588数据：2390
#  9/20 [============>.................] - ETA: 2:17 - loss: 1.4001 - loss_rpn_match: 0.6503 - loss_rpn_bbox: 0.7498数据：2400
# 10/20 [==============>...............] - ETA: 2:04 - loss: 1.4074 - loss_rpn_match: 0.6459 - loss_rpn_bbox: 0.7615数据：2410
# 11/20 [===============>..............] - ETA: 1:52 - loss: 1.4034 - loss_rpn_match: 0.6443 - loss_rpn_bbox: 0.7590数据：2420
# 12/20 [=================>............] - ETA: 1:40 - loss: 1.4031 - loss_rpn_match: 0.6421 - loss_rpn_bbox: 0.7610数据：2430
# 13/20 [==================>...........] - ETA: 1:27 - loss: 1.4029 - loss_rpn_match: 0.6421 - loss_rpn_bbox: 0.7609数据：2440
# 14/20 [====================>.........] - ETA: 1:14 - loss: 1.4027 - loss_rpn_match: 0.6436 - loss_rpn_bbox: 0.7590数据：2450
# 15/20 [=====================>........] - ETA: 1:02 - loss: 1.4025 - loss_rpn_match: 0.6446 - loss_rpn_bbox: 0.7579数据：2460
# 16/20 [=======================>......] - ETA: 50s - loss: 1.4061 - loss_rpn_match: 0.6468 - loss_rpn_bbox: 0.7593 数据：2470
# 17/20 [========================>.....] - ETA: 37s - loss: 1.4075 - loss_rpn_match: 0.6465 - loss_rpn_bbox: 0.7610数据：2480
# 18/20 [==========================>...] - ETA: 25s - loss: 1.4044 - loss_rpn_match: 0.6442 - loss_rpn_bbox: 0.7601数据：2490
# 19/20 [===========================>..] - ETA: 12s - loss: 1.4057 - loss_rpn_match: 0.6445 - loss_rpn_bbox: 0.7612数据：2500
# 20/20 [==============================] - 251s 13s/step - loss: 1.4025 - loss_rpn_match: 0.6436 - loss_rpn_bbox: 0.7588
# Epoch 13/20
# 学习率：6.400000000000001e-05
# 数据：2510
#  1/20 [>.............................] - ETA: 3:55 - loss: 1.3494 - loss_rpn_match: 0.6431 - loss_rpn_bbox: 0.7064数据：2520
#  2/20 [==>...........................] - ETA: 3:42 - loss: 1.3558 - loss_rpn_match: 0.5971 - loss_rpn_bbox: 0.7588数据：2530
#  3/20 [===>..........................] - ETA: 3:31 - loss: 1.3304 - loss_rpn_match: 0.5924 - loss_rpn_bbox: 0.7379数据：2540
#  4/20 [=====>........................] - ETA: 3:14 - loss: 1.3334 - loss_rpn_match: 0.5981 - loss_rpn_bbox: 0.7353数据：2550
#  5/20 [======>.......................] - ETA: 3:00 - loss: 1.3439 - loss_rpn_match: 0.6159 - loss_rpn_bbox: 0.7280数据：2560
#  6/20 [========>.....................] - ETA: 2:47 - loss: 1.3433 - loss_rpn_match: 0.6203 - loss_rpn_bbox: 0.7230数据：2570
#  7/20 [=========>....................] - ETA: 2:34 - loss: 1.3522 - loss_rpn_match: 0.6265 - loss_rpn_bbox: 0.7257数据：2580
#  8/20 [===========>..................] - ETA: 2:21 - loss: 1.3601 - loss_rpn_match: 0.6212 - loss_rpn_bbox: 0.7390数据：2590
#  9/20 [============>.................] - ETA: 2:09 - loss: 1.3560 - loss_rpn_match: 0.6234 - loss_rpn_bbox: 0.7326数据：2600
# 10/20 [==============>...............] - ETA: 1:56 - loss: 1.3661 - loss_rpn_match: 0.6323 - loss_rpn_bbox: 0.7338数据：2610
# 11/20 [===============>..............] - ETA: 1:44 - loss: 1.3640 - loss_rpn_match: 0.6338 - loss_rpn_bbox: 0.7302数据：2620
# 12/20 [=================>............] - ETA: 1:32 - loss: 1.3662 - loss_rpn_match: 0.6289 - loss_rpn_bbox: 0.7373数据：2630
# 13/20 [==================>...........] - ETA: 1:20 - loss: 1.3693 - loss_rpn_match: 0.6312 - loss_rpn_bbox: 0.7381数据：2640
# 14/20 [====================>.........] - ETA: 1:09 - loss: 1.3651 - loss_rpn_match: 0.6335 - loss_rpn_bbox: 0.7316数据：2650
# 15/20 [=====================>........] - ETA: 57s - loss: 1.3613 - loss_rpn_match: 0.6337 - loss_rpn_bbox: 0.7276 数据：2660
# 16/20 [=======================>......] - ETA: 45s - loss: 1.3669 - loss_rpn_match: 0.6328 - loss_rpn_bbox: 0.7341数据：2670
# 17/20 [========================>.....] - ETA: 34s - loss: 1.3640 - loss_rpn_match: 0.6320 - loss_rpn_bbox: 0.7321数据：2680
# 18/20 [==========================>...] - ETA: 22s - loss: 1.3719 - loss_rpn_match: 0.6338 - loss_rpn_bbox: 0.7381数据：2690
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3665 - loss_rpn_match: 0.6319 - loss_rpn_bbox: 0.7345数据：2700
# 20/20 [==============================] - 229s 11s/step - loss: 1.3659 - loss_rpn_match: 0.6312 - loss_rpn_bbox: 0.7347
# Epoch 14/20
# 学习率：6.400000000000001e-05
# 数据：2710
#  1/20 [>.............................] - ETA: 3:53 - loss: 1.3832 - loss_rpn_match: 0.6391 - loss_rpn_bbox: 0.7441数据：2720
#  2/20 [==>...........................] - ETA: 3:40 - loss: 1.3968 - loss_rpn_match: 0.6461 - loss_rpn_bbox: 0.7507数据：2730
#  3/20 [===>..........................] - ETA: 3:24 - loss: 1.3796 - loss_rpn_match: 0.6328 - loss_rpn_bbox: 0.7467数据：2740
#  4/20 [=====>........................] - ETA: 3:12 - loss: 1.4046 - loss_rpn_match: 0.6376 - loss_rpn_bbox: 0.7671数据：2750
#  5/20 [======>.......................] - ETA: 2:59 - loss: 1.4062 - loss_rpn_match: 0.6403 - loss_rpn_bbox: 0.7658数据：2760
#  6/20 [========>.....................] - ETA: 2:46 - loss: 1.4157 - loss_rpn_match: 0.6293 - loss_rpn_bbox: 0.7864数据：2770
#  7/20 [=========>....................] - ETA: 2:35 - loss: 1.4016 - loss_rpn_match: 0.6271 - loss_rpn_bbox: 0.7745数据：2780
#  8/20 [===========>..................] - ETA: 2:22 - loss: 1.4025 - loss_rpn_match: 0.6319 - loss_rpn_bbox: 0.7706数据：2790
#  9/20 [============>.................] - ETA: 2:10 - loss: 1.4074 - loss_rpn_match: 0.6286 - loss_rpn_bbox: 0.7788数据：2800
# 10/20 [==============>...............] - ETA: 1:58 - loss: 1.3988 - loss_rpn_match: 0.6253 - loss_rpn_bbox: 0.7735数据：2810
# 11/20 [===============>..............] - ETA: 1:46 - loss: 1.3926 - loss_rpn_match: 0.6226 - loss_rpn_bbox: 0.7700数据：2820
# 12/20 [=================>............] - ETA: 1:34 - loss: 1.3814 - loss_rpn_match: 0.6201 - loss_rpn_bbox: 0.7613数据：2830
# 13/20 [==================>...........] - ETA: 1:23 - loss: 1.3775 - loss_rpn_match: 0.6219 - loss_rpn_bbox: 0.7556数据：2840
# 14/20 [====================>.........] - ETA: 1:11 - loss: 1.3770 - loss_rpn_match: 0.6238 - loss_rpn_bbox: 0.7531数据：2850
# 15/20 [=====================>........] - ETA: 59s - loss: 1.3703 - loss_rpn_match: 0.6218 - loss_rpn_bbox: 0.7485 数据：2860
# 16/20 [=======================>......] - ETA: 47s - loss: 1.3690 - loss_rpn_match: 0.6191 - loss_rpn_bbox: 0.7499数据：2870
# 17/20 [========================>.....] - ETA: 35s - loss: 1.3694 - loss_rpn_match: 0.6208 - loss_rpn_bbox: 0.7486数据：2880
# 18/20 [==========================>...] - ETA: 23s - loss: 1.3694 - loss_rpn_match: 0.6229 - loss_rpn_bbox: 0.7465数据：2890
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3679 - loss_rpn_match: 0.6237 - loss_rpn_bbox: 0.7442数据：2900
# 20/20 [==============================] - 238s 12s/step - loss: 1.3648 - loss_rpn_match: 0.6226 - loss_rpn_bbox: 0.7422
# Epoch 15/20
# 学习率：5.120000000000001e-05
# 数据：2910
#  1/20 [>.............................] - ETA: 3:49 - loss: 1.3506 - loss_rpn_match: 0.6377 - loss_rpn_bbox: 0.7129数据：2920
#  2/20 [==>...........................] - ETA: 3:38 - loss: 1.3937 - loss_rpn_match: 0.6116 - loss_rpn_bbox: 0.7821数据：2930
#  3/20 [===>..........................] - ETA: 3:33 - loss: 1.3547 - loss_rpn_match: 0.5956 - loss_rpn_bbox: 0.7592数据：2940
#  4/20 [=====>........................] - ETA: 3:21 - loss: 1.3310 - loss_rpn_match: 0.6046 - loss_rpn_bbox: 0.7264数据：2950
#  5/20 [======>.......................] - ETA: 3:08 - loss: 1.3267 - loss_rpn_match: 0.6079 - loss_rpn_bbox: 0.7187数据：2960
#  6/20 [========>.....................] - ETA: 2:54 - loss: 1.3331 - loss_rpn_match: 0.6162 - loss_rpn_bbox: 0.7169数据：2970
#  7/20 [=========>....................] - ETA: 2:40 - loss: 1.3356 - loss_rpn_match: 0.6205 - loss_rpn_bbox: 0.7152数据：2980
#  8/20 [===========>..................] - ETA: 2:27 - loss: 1.3416 - loss_rpn_match: 0.6235 - loss_rpn_bbox: 0.7181数据：2990
#  9/20 [============>.................] - ETA: 2:14 - loss: 1.3432 - loss_rpn_match: 0.6288 - loss_rpn_bbox: 0.7144数据：3000
# 10/20 [==============>...............] - ETA: 2:02 - loss: 1.3444 - loss_rpn_match: 0.6295 - loss_rpn_bbox: 0.7149数据：3010
# 11/20 [===============>..............] - ETA: 1:50 - loss: 1.3432 - loss_rpn_match: 0.6278 - loss_rpn_bbox: 0.7154数据：3020
# 12/20 [=================>............] - ETA: 1:37 - loss: 1.3464 - loss_rpn_match: 0.6284 - loss_rpn_bbox: 0.7180数据：3030
# 13/20 [==================>...........] - ETA: 1:25 - loss: 1.3528 - loss_rpn_match: 0.6280 - loss_rpn_bbox: 0.7248数据：3040
# 14/20 [====================>.........] - ETA: 1:13 - loss: 1.3546 - loss_rpn_match: 0.6261 - loss_rpn_bbox: 0.7285数据：3050
# 15/20 [=====================>........] - ETA: 1:01 - loss: 1.3536 - loss_rpn_match: 0.6258 - loss_rpn_bbox: 0.7277数据：3060
# 16/20 [=======================>......] - ETA: 49s - loss: 1.3591 - loss_rpn_match: 0.6269 - loss_rpn_bbox: 0.7322 数据：3070
# 17/20 [========================>.....] - ETA: 36s - loss: 1.3651 - loss_rpn_match: 0.6270 - loss_rpn_bbox: 0.7381数据：3080
# 18/20 [==========================>...] - ETA: 24s - loss: 1.3656 - loss_rpn_match: 0.6294 - loss_rpn_bbox: 0.7363数据：3090
# 19/20 [===========================>..] - ETA: 12s - loss: 1.3682 - loss_rpn_match: 0.6284 - loss_rpn_bbox: 0.7398数据：3100
# 20/20 [==============================] - 246s 12s/step - loss: 1.3672 - loss_rpn_match: 0.6299 - loss_rpn_bbox: 0.7373
# Epoch 16/20
# 学习率：5.120000000000001e-05
# 数据：3110
#  1/20 [>.............................] - ETA: 3:40 - loss: 1.4290 - loss_rpn_match: 0.6216 - loss_rpn_bbox: 0.8074数据：3120
#  2/20 [==>...........................] - ETA: 3:32 - loss: 1.3579 - loss_rpn_match: 0.6105 - loss_rpn_bbox: 0.7475数据：3130
#  3/20 [===>..........................] - ETA: 3:28 - loss: 1.3685 - loss_rpn_match: 0.6306 - loss_rpn_bbox: 0.7379数据：3140
#  4/20 [=====>........................] - ETA: 3:17 - loss: 1.3872 - loss_rpn_match: 0.6208 - loss_rpn_bbox: 0.7663数据：3150
#  5/20 [======>.......................] - ETA: 3:05 - loss: 1.3828 - loss_rpn_match: 0.6207 - loss_rpn_bbox: 0.7622数据：3160
#  6/20 [========>.....................] - ETA: 2:52 - loss: 1.3828 - loss_rpn_match: 0.6202 - loss_rpn_bbox: 0.7626数据：3170
#  7/20 [=========>....................] - ETA: 2:39 - loss: 1.3952 - loss_rpn_match: 0.6238 - loss_rpn_bbox: 0.7713数据：3180
#  8/20 [===========>..................] - ETA: 2:26 - loss: 1.3974 - loss_rpn_match: 0.6256 - loss_rpn_bbox: 0.7718数据：3190
#  9/20 [============>.................] - ETA: 2:14 - loss: 1.3849 - loss_rpn_match: 0.6251 - loss_rpn_bbox: 0.7598数据：3200
# 10/20 [==============>...............] - ETA: 2:01 - loss: 1.3822 - loss_rpn_match: 0.6280 - loss_rpn_bbox: 0.7542数据：3210
# 11/20 [===============>..............] - ETA: 1:49 - loss: 1.3806 - loss_rpn_match: 0.6300 - loss_rpn_bbox: 0.7506数据：3220
# 12/20 [=================>............] - ETA: 1:36 - loss: 1.3706 - loss_rpn_match: 0.6269 - loss_rpn_bbox: 0.7436数据：3230
# 13/20 [==================>...........] - ETA: 1:24 - loss: 1.3643 - loss_rpn_match: 0.6253 - loss_rpn_bbox: 0.7390数据：3240
# 14/20 [====================>.........] - ETA: 1:12 - loss: 1.3648 - loss_rpn_match: 0.6198 - loss_rpn_bbox: 0.7450数据：3250
# 15/20 [=====================>........] - ETA: 1:00 - loss: 1.3668 - loss_rpn_match: 0.6168 - loss_rpn_bbox: 0.7500数据：3260
# 16/20 [=======================>......] - ETA: 48s - loss: 1.3623 - loss_rpn_match: 0.6162 - loss_rpn_bbox: 0.7461 数据：3270
# 17/20 [========================>.....] - ETA: 36s - loss: 1.3674 - loss_rpn_match: 0.6179 - loss_rpn_bbox: 0.7495数据：3280
# 18/20 [==========================>...] - ETA: 24s - loss: 1.3648 - loss_rpn_match: 0.6189 - loss_rpn_bbox: 0.7460数据：3290
# 19/20 [===========================>..] - ETA: 12s - loss: 1.3633 - loss_rpn_match: 0.6175 - loss_rpn_bbox: 0.7458数据：3300
# 20/20 [==============================] - 241s 12s/step - loss: 1.3686 - loss_rpn_match: 0.6162 - loss_rpn_bbox: 0.7524
# Epoch 17/20
# 学习率：5.120000000000001e-05
# 数据：3310
#  1/20 [>.............................] - ETA: 3:37 - loss: 1.3693 - loss_rpn_match: 0.6267 - loss_rpn_bbox: 0.7426数据：3320
#  2/20 [==>...........................] - ETA: 3:27 - loss: 1.3825 - loss_rpn_match: 0.6232 - loss_rpn_bbox: 0.7593数据：3330
#  3/20 [===>..........................] - ETA: 3:12 - loss: 1.3993 - loss_rpn_match: 0.6371 - loss_rpn_bbox: 0.7621数据：3340
#  4/20 [=====>........................] - ETA: 3:05 - loss: 1.4006 - loss_rpn_match: 0.6337 - loss_rpn_bbox: 0.7669数据：3350
#  5/20 [======>.......................] - ETA: 2:55 - loss: 1.3887 - loss_rpn_match: 0.6353 - loss_rpn_bbox: 0.7535数据：3360
#  6/20 [========>.....................] - ETA: 2:43 - loss: 1.3887 - loss_rpn_match: 0.6407 - loss_rpn_bbox: 0.7480数据：3370
#  7/20 [=========>....................] - ETA: 2:31 - loss: 1.3771 - loss_rpn_match: 0.6379 - loss_rpn_bbox: 0.7391数据：3380
#  8/20 [===========>..................] - ETA: 2:19 - loss: 1.3769 - loss_rpn_match: 0.6407 - loss_rpn_bbox: 0.7362数据：3390
#  9/20 [============>.................] - ETA: 2:07 - loss: 1.3703 - loss_rpn_match: 0.6400 - loss_rpn_bbox: 0.7303数据：3400
# 10/20 [==============>...............] - ETA: 1:56 - loss: 1.3661 - loss_rpn_match: 0.6347 - loss_rpn_bbox: 0.7315数据：3410
# 11/20 [===============>..............] - ETA: 1:44 - loss: 1.3715 - loss_rpn_match: 0.6347 - loss_rpn_bbox: 0.7368数据：3420
# 12/20 [=================>............] - ETA: 1:32 - loss: 1.3731 - loss_rpn_match: 0.6325 - loss_rpn_bbox: 0.7406数据：3430
# 13/20 [==================>...........] - ETA: 1:21 - loss: 1.3691 - loss_rpn_match: 0.6335 - loss_rpn_bbox: 0.7356数据：3440
# 14/20 [====================>.........] - ETA: 1:10 - loss: 1.3833 - loss_rpn_match: 0.6361 - loss_rpn_bbox: 0.7472数据：3450
# 15/20 [=====================>........] - ETA: 58s - loss: 1.3778 - loss_rpn_match: 0.6367 - loss_rpn_bbox: 0.7411 数据：3460
# 16/20 [=======================>......] - ETA: 46s - loss: 1.3783 - loss_rpn_match: 0.6370 - loss_rpn_bbox: 0.7413数据：3470
# 17/20 [========================>.....] - ETA: 35s - loss: 1.3832 - loss_rpn_match: 0.6340 - loss_rpn_bbox: 0.7492数据：3480
# 18/20 [==========================>...] - ETA: 23s - loss: 1.3820 - loss_rpn_match: 0.6312 - loss_rpn_bbox: 0.7508数据：3490
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3778 - loss_rpn_match: 0.6304 - loss_rpn_bbox: 0.7475数据：3500
# 20/20 [==============================] - 231s 12s/step - loss: 1.3739 - loss_rpn_match: 0.6300 - loss_rpn_bbox: 0.7440
# Epoch 18/20
# 学习率：5.120000000000001e-05
# 数据：3510
#  1/20 [>.............................] - ETA: 3:38 - loss: 1.2970 - loss_rpn_match: 0.6481 - loss_rpn_bbox: 0.6489数据：3520
#  2/20 [==>...........................] - ETA: 3:24 - loss: 1.3641 - loss_rpn_match: 0.6205 - loss_rpn_bbox: 0.7435数据：3530
#  3/20 [===>..........................] - ETA: 3:14 - loss: 1.3432 - loss_rpn_match: 0.6230 - loss_rpn_bbox: 0.7203数据：3540
#  4/20 [=====>........................] - ETA: 3:02 - loss: 1.3388 - loss_rpn_match: 0.6112 - loss_rpn_bbox: 0.7276数据：3550
#  5/20 [======>.......................] - ETA: 2:51 - loss: 1.3444 - loss_rpn_match: 0.6125 - loss_rpn_bbox: 0.7319数据：3560
#  6/20 [========>.....................] - ETA: 2:40 - loss: 1.3601 - loss_rpn_match: 0.6263 - loss_rpn_bbox: 0.7338数据：3570
#  7/20 [=========>....................] - ETA: 2:28 - loss: 1.3498 - loss_rpn_match: 0.6239 - loss_rpn_bbox: 0.7259数据：3580
#  8/20 [===========>..................] - ETA: 2:17 - loss: 1.3448 - loss_rpn_match: 0.6238 - loss_rpn_bbox: 0.7209数据：3590
#  9/20 [============>.................] - ETA: 2:06 - loss: 1.3490 - loss_rpn_match: 0.6264 - loss_rpn_bbox: 0.7226数据：3600
# 10/20 [==============>...............] - ETA: 1:55 - loss: 1.3548 - loss_rpn_match: 0.6259 - loss_rpn_bbox: 0.7289数据：3610
# 11/20 [===============>..............] - ETA: 1:43 - loss: 1.3502 - loss_rpn_match: 0.6219 - loss_rpn_bbox: 0.7283数据：3620
# 12/20 [=================>............] - ETA: 1:32 - loss: 1.3497 - loss_rpn_match: 0.6231 - loss_rpn_bbox: 0.7266数据：3630
# 13/20 [==================>...........] - ETA: 1:21 - loss: 1.3504 - loss_rpn_match: 0.6218 - loss_rpn_bbox: 0.7285数据：3640
# 14/20 [====================>.........] - ETA: 1:09 - loss: 1.3454 - loss_rpn_match: 0.6213 - loss_rpn_bbox: 0.7241数据：3650
# 15/20 [=====================>........] - ETA: 57s - loss: 1.3436 - loss_rpn_match: 0.6187 - loss_rpn_bbox: 0.7249 数据：3660
# 16/20 [=======================>......] - ETA: 46s - loss: 1.3483 - loss_rpn_match: 0.6199 - loss_rpn_bbox: 0.7284数据：3670
# 17/20 [========================>.....] - ETA: 34s - loss: 1.3440 - loss_rpn_match: 0.6177 - loss_rpn_bbox: 0.7263数据：3680
# 18/20 [==========================>...] - ETA: 22s - loss: 1.3435 - loss_rpn_match: 0.6156 - loss_rpn_bbox: 0.7279数据：3690
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3436 - loss_rpn_match: 0.6172 - loss_rpn_bbox: 0.7264数据：3700
# 20/20 [==============================] - 230s 12s/step - loss: 1.3441 - loss_rpn_match: 0.6154 - loss_rpn_bbox: 0.7286
# Epoch 19/20
# 学习率：5.120000000000001e-05
# 数据：3710
#  1/20 [>.............................] - ETA: 3:40 - loss: 1.3143 - loss_rpn_match: 0.6504 - loss_rpn_bbox: 0.6639数据：3720
#  2/20 [==>...........................] - ETA: 3:25 - loss: 1.2817 - loss_rpn_match: 0.6184 - loss_rpn_bbox: 0.6632数据：3730
#  3/20 [===>..........................] - ETA: 3:15 - loss: 1.3098 - loss_rpn_match: 0.6341 - loss_rpn_bbox: 0.6756数据：3740
#  4/20 [=====>........................] - ETA: 3:02 - loss: 1.3051 - loss_rpn_match: 0.6378 - loss_rpn_bbox: 0.6673数据：3750
#  5/20 [======>.......................] - ETA: 2:50 - loss: 1.2859 - loss_rpn_match: 0.6212 - loss_rpn_bbox: 0.6647数据：3760
#  6/20 [========>.....................] - ETA: 2:39 - loss: 1.2894 - loss_rpn_match: 0.6125 - loss_rpn_bbox: 0.6769数据：3770
#  7/20 [=========>....................] - ETA: 2:27 - loss: 1.2924 - loss_rpn_match: 0.6156 - loss_rpn_bbox: 0.6768数据：3780
#  8/20 [===========>..................] - ETA: 2:15 - loss: 1.2870 - loss_rpn_match: 0.6121 - loss_rpn_bbox: 0.6749数据：3790
#  9/20 [============>.................] - ETA: 2:04 - loss: 1.2996 - loss_rpn_match: 0.6079 - loss_rpn_bbox: 0.6917数据：3800
# 10/20 [==============>...............] - ETA: 1:53 - loss: 1.3052 - loss_rpn_match: 0.6104 - loss_rpn_bbox: 0.6948数据：3810
# 11/20 [===============>..............] - ETA: 1:42 - loss: 1.3119 - loss_rpn_match: 0.6137 - loss_rpn_bbox: 0.6982数据：3820
# 12/20 [=================>............] - ETA: 1:30 - loss: 1.3171 - loss_rpn_match: 0.6184 - loss_rpn_bbox: 0.6987数据：3830
# 13/20 [==================>...........] - ETA: 1:18 - loss: 1.3119 - loss_rpn_match: 0.6167 - loss_rpn_bbox: 0.6952数据：3840
# 14/20 [====================>.........] - ETA: 1:07 - loss: 1.3143 - loss_rpn_match: 0.6139 - loss_rpn_bbox: 0.7004数据：3850
# 15/20 [=====================>........] - ETA: 56s - loss: 1.3152 - loss_rpn_match: 0.6140 - loss_rpn_bbox: 0.7012 数据：3860
# 16/20 [=======================>......] - ETA: 44s - loss: 1.3162 - loss_rpn_match: 0.6159 - loss_rpn_bbox: 0.7003数据：3870
# 17/20 [========================>.....] - ETA: 33s - loss: 1.3118 - loss_rpn_match: 0.6138 - loss_rpn_bbox: 0.6980数据：3880
# 18/20 [==========================>...] - ETA: 22s - loss: 1.3168 - loss_rpn_match: 0.6138 - loss_rpn_bbox: 0.7030数据：3890
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3156 - loss_rpn_match: 0.6144 - loss_rpn_bbox: 0.7012数据：3900
# 20/20 [==============================] - 226s 11s/step - loss: 1.3132 - loss_rpn_match: 0.6149 - loss_rpn_bbox: 0.6983
# Epoch 20/20
# 学习率：4.096000000000001e-05
# 数据：3910
#  1/20 [>.............................] - ETA: 3:34 - loss: 1.3658 - loss_rpn_match: 0.6356 - loss_rpn_bbox: 0.7302数据：3920
#  2/20 [==>...........................] - ETA: 3:26 - loss: 1.3471 - loss_rpn_match: 0.6134 - loss_rpn_bbox: 0.7337数据：3930
#  3/20 [===>..........................] - ETA: 3:17 - loss: 1.3659 - loss_rpn_match: 0.6128 - loss_rpn_bbox: 0.7531数据：3940
#  4/20 [=====>........................] - ETA: 3:09 - loss: 1.3607 - loss_rpn_match: 0.6105 - loss_rpn_bbox: 0.7502数据：3950
#  5/20 [======>.......................] - ETA: 2:57 - loss: 1.3700 - loss_rpn_match: 0.6094 - loss_rpn_bbox: 0.7607数据：3960
#  6/20 [========>.....................] - ETA: 2:45 - loss: 1.3683 - loss_rpn_match: 0.6175 - loss_rpn_bbox: 0.7508数据：3970
#  7/20 [=========>....................] - ETA: 2:34 - loss: 1.3608 - loss_rpn_match: 0.6209 - loss_rpn_bbox: 0.7399数据：3980
#  8/20 [===========>..................] - ETA: 2:22 - loss: 1.3572 - loss_rpn_match: 0.6233 - loss_rpn_bbox: 0.7338数据：3990
#  9/20 [============>.................] - ETA: 2:10 - loss: 1.3575 - loss_rpn_match: 0.6250 - loss_rpn_bbox: 0.7324数据：4000
# 10/20 [==============>...............] - ETA: 1:57 - loss: 1.3572 - loss_rpn_match: 0.6260 - loss_rpn_bbox: 0.7312数据：4010
# 11/20 [===============>..............] - ETA: 1:45 - loss: 1.3607 - loss_rpn_match: 0.6256 - loss_rpn_bbox: 0.7351数据：4020
# 12/20 [=================>............] - ETA: 1:33 - loss: 1.3546 - loss_rpn_match: 0.6255 - loss_rpn_bbox: 0.7291数据：4030
# 13/20 [==================>...........] - ETA: 1:21 - loss: 1.3559 - loss_rpn_match: 0.6272 - loss_rpn_bbox: 0.7287数据：4040
# 14/20 [====================>.........] - ETA: 1:09 - loss: 1.3589 - loss_rpn_match: 0.6268 - loss_rpn_bbox: 0.7321数据：4050
# 15/20 [=====================>........] - ETA: 57s - loss: 1.3541 - loss_rpn_match: 0.6253 - loss_rpn_bbox: 0.7288 数据：4060
# 16/20 [=======================>......] - ETA: 46s - loss: 1.3576 - loss_rpn_match: 0.6267 - loss_rpn_bbox: 0.7309数据：4070
# 17/20 [========================>.....] - ETA: 34s - loss: 1.3519 - loss_rpn_match: 0.6236 - loss_rpn_bbox: 0.7283数据：4080
# 18/20 [==========================>...] - ETA: 22s - loss: 1.3655 - loss_rpn_match: 0.6194 - loss_rpn_bbox: 0.7461数据：4090
# 19/20 [===========================>..] - ETA: 11s - loss: 1.3882 - loss_rpn_match: 0.6181 - loss_rpn_bbox: 0.7701数据：4100
# 20/20 [==============================] - 227s 11s/step - loss: 1.3915 - loss_rpn_match: 0.6185 - loss_rpn_bbox: 0.7730

# %%
# 将anchors根据计算出的修正量逆运算出实际计算的anchors
# anchors：锚框
# deltas：网络计算出的修正量
def anchor_refinement(anchors, deltas):
    boxes = tf.cast(anchors, tf.float32)
    h = boxes[:, 2] - boxes[:, 0]
    w = boxes[:, 3] - boxes[:, 1]
    center_y = boxes[:, 0] + h / 2
    center_x = boxes[:, 1] + w / 2

    center_y += deltas[:, 0] * h
    center_x += deltas[:, 1] * w
    h *= tf.exp(deltas[:, 2])
    w *= tf.exp(deltas[:, 3])
    
    y1 = center_y - h / 2
    x1 = center_x - w / 2
    y2 = center_y + h / 2
    x2 = center_x + w / 2
    boxes = tf.stack([y1, x1, y2, x2], axis=1)
    return boxes

# 限定坐标的边界，不超过边界
def boxes_clip(boxes, window):
    wy1, wx1, wy2, wx2 = tf.split(window, 4)
    y1, x1, y2, x2 = tf.split(boxes, 4, axis=1)
    y1 = tf.maximum(tf.minimum(y1, wy2), wy1)
    x1 = tf.maximum(tf.minimum(x1, wx2), wx1)
    y2 = tf.maximum(tf.minimum(y2, wy2), wy1)
    x2 = tf.maximum(tf.minimum(x2, wx2), wx1)
    cliped = tf.concat([y1, x1, y2, x2], axis=1)
    cliped.set_shape((cliped.shape[0], 4))
    return cliped

# 将输入的inputs 按提供的 graph_fn方法进行切片
# 因为数据是batch_size个的数组，所以这个函数是进行batch_size个数组的操作
def batch_slice(inputs, graph_fn, batch_size):
    if not isinstance(inputs, list):
        inputs = [inputs]
    output = []
    for i in range(batch_size):
        inputs_slice = [x[i] for x in inputs]
        output_slice = graph_fn(*inputs_slice)
        if not isinstance(output_slice, (list, tuple)):
            output_slice = [output_slice]
        output.append(output_slice)
    # 打包输出出去
    output = list(zip(*output))
    result = [tf.stack(o, axis=0) for o in output]
    if len(result)==1:
        result = result[0]
    return result


import keras.engine as KE
class proposal(KE.Layer):
    # proposal_count：保留的框个数
    # nms_thresh：超过这个阈值，两个anchor就去pk
    # anchors：锚框
    # batch_size
    # config：配置项
    # kwargs：其他参数
    def __init__(self, proposal_count, nms_thresh, anchors, batch_size, config=None, **kwargs):
        super(proposal, self).__init__(**kwargs)
        self.proposal_count = proposal_count
        self.anchors = anchors
        self.nms_thresh = nms_thresh
        self.batch_size = batch_size
        self.config = config
    
    # input：输入的 probs置信度inputs[0] 和 deltas修正量inputs[1]
    def call(self, inputs):
        # 取最后一维（前景概率）
        probs = inputs[0][:, :, 1]
        # 修正量
        deltas = inputs[1]
        # -------------------------------- 取得分前100的锚框数据 --------------------------------
        # 乘RPN_BBOX_STD_DEV，是因为build_rpnTarget函数里面除以了这个数，避免值太小
        deltas = deltas * np.reshape(self.config.RPN_BBOX_STD_DEV, (1, 1, 4))
        # 判断：取100和anchors数之间最小
        prenms_num = min(100, self.anchors.shape[0])
        # 取前100个锚框得分最高的锚框下标
        idxs = tf.nn.top_k(probs, prenms_num).indices
        
        # 按坐标取元素
        # 置信度
        probs = batch_slice([probs, idxs], lambda x,y:tf.gather(x, y), self.batch_size)
        # 修正量
        deltas = batch_slice([deltas, idxs], lambda x,y:tf.gather(x, y), self.batch_size)
        # 锚框
        anchors = batch_slice([idxs], lambda x:tf.gather(self.anchors,x), self.batch_size)

        # ----------------------------------------- 修正 -----------------------------------------
        # 取修正框
        refined_boxes = batch_slice([anchors, deltas], lambda x,y:anchor_refinement(x,y), self.batch_size)
        # 限定坐标的边界，不超过边界，避免修到外面去
        H,W = self.config.image_size[:2]
        windows = np.array([0,0,H,W]).astype(np.float32)
        cliped_boxes = batch_slice([refined_boxes], lambda x:boxes_clip(x, windows), self.batch_size)
        
        # 归一化
        normalized_boxes = cliped_boxes / np.array([H,W,H,W])
        # 非极大值抑制方法
        def nms(normalized_boxes, scores):
            idxs_ = tf.image.non_max_suppression(normalized_boxes, scores, self.proposal_count, self.nms_thresh)
            box = tf.gather(normalized_boxes, idxs_)
            pad_num = tf.maximum(self.proposal_count - tf.shape(normalized_boxes)[0],0)
            box = tf.pad(box, [(0,pad_num),(0,0)])
            return box
        # 进行非极大值抑制切换
        proposal_ = batch_slice([normalized_boxes, probs], nms, self.batch_size)
        return proposal_
    
    def compute_output_shape(self, input_shape):
        return (None, self.proposal_count, 4)

# %%
test_data = next(dataGen)[0]
images = test_data[0]
bboxes = test_data[1]
class_ids = test_data[2]
rpn_matchs = test_data[3]
rpn_bboxes = test_data[4]
print(images.shape)
rpn_class, rpn_prob, rpn_bbox, _, _ = \
                model.predict([images, bboxes, class_ids, rpn_matchs, rpn_bboxes])
# 转tensor
rpn_class = tf.convert_to_tensor(rpn_class)
rpn_prob = tf.convert_to_tensor(rpn_prob)
rpn_bbox = tf.convert_to_tensor(rpn_bbox)
# Out:
# 数据：4110
# (10, 320, 320, 3)

# %%
# import utils
# change
proposals = proposal(proposal_count=20, nms_thresh=0.7, anchors=anchors, batch_size=config.batch_size, config=config)([rpn_prob, rpn_bbox])

# %%
sess = tf.Session()
proposals_ = sess.run(proposals) * image_size # change

# %%
import random

ix = 4
# ix = random.sample(range(batch_size), 1)[0]
proposal_ = proposals_[ix]
img = images[ix]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

plt.imshow(img)
axs = plt.gca()
print(proposal_)
for i in range(10):
    box = proposal_[i]
    rec = patches.Rectangle((box[0], box[1]), box[2]-box[0], box[3]-box[1], facecolor='none', edgecolor='r')
    axs.add_patch(rec)
# Out:
# [[188.14487  161.63759  231.11078  239.78314 ]
#  [188.44412  129.65434  222.33316  213.72043 ]
#  [210.71399  181.96375  267.09964  237.47684 ]
#  [184.43192  136.70694  228.71951  230.64703 ]
#  [ 34.698196 110.82492   87.299614 200.26172 ]
#  [207.99222  143.86452  269.92386  211.96861 ]
#  [  0.         4.935936  66.646     85.9724  ]
#  [ 39.47328  163.10779   88.14701  238.40076 ]
#  [ 83.104294  54.061417 235.57178  141.01593 ]
#  [155.37248   83.627304 196.07639  182.62112 ]
#  [267.24072   47.985275 308.64844  136.86728 ]
#  [  0.       126.69414  111.752106 218.54185 ]
#  [  0.       182.82635   97.34267  267.52084 ]
#  [153.10497  177.98883  199.52405  282.46176 ]
#  [ 81.206894  95.69833  242.04973  188.76797 ]
#  [271.3628    64.42257  308.50568  154.07635 ]
#  [ 92.684814 141.50304  270.74545  230.82233 ]
#  [203.46884  234.40842  320.       320.      ]
#  [151.84752  128.02606  195.4434   203.25168 ]
#  [208.37283  162.61136  263.48373  217.64734 ]]
